# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
df = pd.read_json("data.json")
df
# Out:
#         acc_x     acc_y     acc_z      rr_a      rr_b      rr_g
# 0    0.870143 -4.061314 -8.905832  1.212864  3.197383  1.911294
# 1    0.850839 -4.069244 -8.881890  0.906175  2.973090  1.937514
# 2    0.854730 -4.084807 -8.913762  0.166580  1.645044  1.462776
# 3    0.856974 -4.093187 -8.923938 -0.178057  0.187665  1.138484
# 4    0.861613 -4.096179 -8.901342 -0.494463  0.312909  1.434153
# ..        ...       ...       ...       ...       ...       ...
# 161  1.682675 -3.771615 -8.899248 -2.320697 -1.088182 -1.557808
# 162  1.674146 -3.813813 -8.906580 -2.327611 -0.953659 -1.037761
# 163  1.698237 -3.821295 -8.902689 -2.051398 -0.368268 -0.974358
# 164  1.693299 -3.757998 -8.858995 -2.213392  0.426039 -1.002347
# 165  1.666364 -3.789722 -8.877850 -3.487419 -1.092045 -1.374365
#
# [166 rows x 6 columns]

# %%
# motion data
df.plot(figsize=(30,15))
df[["acc_x","acc_y","acc_z"]].plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# motion data (on table)
df_rotate = pd.read_json("data10.json")
df_rotate.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# motion data (in hand)
df_rotate = pd.read_json("data11.json")
df_rotate.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# orientation data (on table)
df_rotate = pd.read_json("data_orient5.json")
df_rotate.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# orientation data (in hand)
df_rotate = pd.read_json("data_orient6.json")
df_rotate.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df_rotate.iloc[60:80]
# Out:
#              a          b          g
# 60   76.950564 -29.251283 -61.957407
# 61   76.819301 -29.858822 -62.568059
# 62   76.662996 -30.219467 -62.783763
# 63   76.217414 -31.042764 -62.938908
# 64   75.652867 -31.964711 -62.861637
# 65   75.367385 -32.427984 -62.780779
# 66   74.900734 -33.285411 -62.609089
# 67   74.698157 -33.971271 -62.601091
# 68   74.667498 -34.194999 -62.727036
# 69   74.750284 -34.495255 -63.135381
# 70  358.755288  11.603108  21.443970
# 71  359.015294  14.569247  21.098174
# 72  358.779342  14.930634  20.651749
# 73  358.268731  14.778584  20.401608
# 74  358.049289  14.289093  20.159651
# 75  358.008816  14.046793  20.147073
# 76  358.178375  13.867308  20.181348
# 77  358.593382  14.207818  20.348218
# 78  358.790158  14.517594  20.529753
# 79  359.052414  15.114886  21.091263

# %%
df_orient = pd.read_json("data_orient24.json")
df_orient.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
[df_orient.iloc[0],df_orient.iloc[150],df_orient.iloc[300],df_orient.iloc[450]]
# Out:
# [a    169.251354
#  b      0.434179
#  g      0.184611
#  Name: 0, dtype: float64,
#  a    77.794028
#  b     0.277701
#  g     0.478936
#  Name: 150, dtype: float64,
#  a    350.415032
#  b      0.070392
#  g      0.523035
#  Name: 300, dtype: float64,
#  a    258.307793
#  b     -0.048445
#  g      0.241384
#  Name: 450, dtype: float64]
